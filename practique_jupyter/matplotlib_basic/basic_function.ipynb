# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5, 6, 7, 8, 9])
plt.ylabel("Number y")
plt.xlabel("Number x")
plt.show()

# %%
plt.plot([1, 2, 3, 4, 5, 6, 7], [1, 3, 6, 21, 34, 45, 46])#versatile function, build in an arbitrary way taking the given elements

# %%
plt.plot([1, 2, 3, 4, 5, 6, 7], [1, 3, 6, 21, 34, 45, 46], 'ro')
plt.axis((0, 8, 0, 50))#[xmin, xmax, ymin, ymax]
plt.show()

# %%
import numpy as np
example = np.arange(0., 7., 0.3)
plt.plot(example, example, 'r--', example, example**2, 'bs', example, example**3, 'g^')#transfer of different styles of a matrix generated with numpy
plt.show()

# %% [markdown]
# Plotting with keyword strings

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# Plot with categorical variables

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
names_group = ['group_1', 'group_2', 'group_3']
values = [23, 200, 500]

plt.figure(figsize=(12, 4))

plt.subplot(131)# subplot(nrows, ncols, index, **kwargs)
plt.bar(names_group, values)
plt.subplot(132)
plt.scatter(names_group, values)
plt.subplot(133)
plt.plot(names_group, values)

plt.suptitle('Category group')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(90000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='r', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
